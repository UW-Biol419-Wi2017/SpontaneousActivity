# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn import linear_model
# %matplotlib inline

# %%
data = pd.read_csv('ExpressionR50.csv', header =None)
rows = pd.read_csv('RowsR50.csv')
age = np.array([12, 13, 13, 12, 16, 17, 21, 21, 24, 35, 37])
gene_id = rows.ix[:,2]
data_id = pd.concat([data, gene_id], axis=1)
new_data = data_id[data_id['gene-id']!= 0]
clean_data = new_data.ix[:,:-1]

# %%
just_data = new_data.ix[:,:11]
just_dataT = just_data.T

# %%
genes_pca = PCA()
genes_pc = genes_pca.fit_transform(just_dataT)

# %%
print(genes_pca.explained_variance_ratio_)
# Out:
# [  5.52523295e-01   1.64026867e-01   8.90240697e-02   4.87904868e-02
#    4.43305194e-02   3.44542972e-02   2.15485343e-02   1.81371253e-02
#    1.58532208e-02   1.13115844e-02   2.64330765e-31]

# %%
result = -1
Cumsum = genes_pca.explained_variance_ratio_.cumsum()
for i in range(len(Cumsum)):
    if Cumsum[i]>=0.9:
        result = i
        break
print(result,"th PC")
# Out:
# 5 th PC

# %%
genes_red = genes_pca.transform(just_dataT)

# %%
plt.scatter(genes_red[:,0].flatten(),age)
plt.xlabel('PC 1')
plt.ylabel('Age')
plt.title('Age vs PC 1')

regr = linear_model.LinearRegression()
regr.fit(genes_red[:,0],age)
# Out:
# /Users/sandyliang/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-110-a637f8b096f3> in <module>()
#       5
#       6 regr = linear_model.LinearRegression()
# ----> 7 regr.fit(genes_red[:,0],age)
#
# /Users/sandyliang/anaconda/lib/python3.5/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 427                          y_numeric=True, multi_output=True)
#     428
#     429         if ((sample_weight is not None) and np.atleast_1d(sample_weight).ndim > 1):
#
# /Users/sandyliang/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     518         y = y.astype(np.float64)
#     519
# --> 520     check_consistent_length(X, y)
#     521
#     522     return X, y
#
# /Users/sandyliang/anaconda/lib/python3.5/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     174     if len(uniques) > 1:
#     175         raise ValueError("Found arrays with inconsistent numbers of samples: "
# --> 176                          "%s" % str(uniques))
#     177
#     178
#
# ValueError: Found arrays with inconsistent numbers of samples: [ 1 11]

# %%
fig = plt.figure()
plt.scatter(genes_red[:,0].flatten(),age)
plt.xlabel('PC 1')
plt.ylabel('Age')
plt.title('Age vs PC 1')

fig = plt.figure()
plt.scatter(genes_red[:,1].flatten(),age)
plt.xlabel('PC 2')
plt.ylabel('Age')
plt.title('Age vs PC 2')

fig = plt.figure()
plt.scatter(genes_red[:,0].flatten(),genes_red[:,1].flatten())
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('PC 2 vs PC 1')

# %%
plt.scatter(x=genes_pc[:,0],y=genes_pc[:,1])
plt.xlabel('PC1')    
plt.ylabel('PC2')

# %%
km = KMeans(n_clusters = 2)
clusters = km.fit(genes_pc)

labels = km.labels_

plt.scatter(genes_pc[:,0],genes_pc[:,1],
            alpha=0.75, c=labels, cmap='rainbow')


plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA then K-Means: PC2 vs PC 1 ")

# %%
km = KMeans(n_clusters = 2)
clusters = km.fit(genes_pc)

labels = km.labels_

plt.scatter(genes_pc[:,0],genes_pc[:,1],
            alpha=0.75, c=labels, cmap='rainbow')


Cov = np.dot(genes_pc.T, genes_pc) / len(genes_pc)
T, D = np.linalg.eig(Cov)

plt.plot(genes_pc[:,0], genes_pc[:,1], 'k.', alpha=0.2)

pc1 = D[:, 1] * T[1]
plt.plot([0, pc1[0]], [0, pc1[1]], 'r-', linewidth=3)
plt.ylim(-20,20)

plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA, K-Means, Eigen: PC2 vs PC 1 ")

# %%
pd.DataFrame(new_data.ix[:,-1:]).head()
Predict = pd.DataFrame(labels)

# %%
#Data_Predict = np.column_stack((new_data.iloc[:,11:13], Predict))
#GeneID_Predict = pd.DataFrame(Data_Predict[:,:])

# %%
cluster0 = GeneID_Predict[GeneID_Predict[1]== 0]
cluster1 = GeneID_Predict[GeneID_Predict[1]== 1]
cluster2 = GeneID_Predict[GeneID_Predict[1]== 2]
cluster3 = GeneID_Predict[GeneID_Predict[1]== 3]
cluster4 = GeneID_Predict[GeneID_Predict[1]== 4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-2a53e80a5d6b> in <module>()
# ----> 1 cluster0 = GeneID_Predict[GeneID_Predict[1]== 0]
#       2 cluster1 = GeneID_Predict[GeneID_Predict[1]== 1]
#       3 cluster2 = GeneID_Predict[GeneID_Predict[1]== 2]
#       4 cluster3 = GeneID_Predict[GeneID_Predict[1]== 3]
#       5 cluster4 = GeneID_Predict[GeneID_Predict[1]== 4]
#
# NameError: name 'GeneID_Predict' is not defined

# %%
Cluster0_genes = cluster0.iloc[:,0:1].values
Cluster1_genes = cluster1.iloc[:,0:1].values
Cluster2_genes = cluster2.iloc[:,0:1].values
Cluster3_genes = cluster3.iloc[:,0:1].values
Cluster4_genes = cluster4.iloc[:,0:1].values

# %%
m = np.polyfit(genes_pc[:,0],genes_pc[:,1],1)
plt.plot(genes_pc[:,0], m[0]*genes_pc[:,0] + m[1], color='r')

# %%
km = KMeans(n_clusters = 2)
clusters = km.fit(genes_pc)

labels = km.labels_

plt.scatter(genes_pc[:,0],genes_pc[:,1],
            alpha=0.75, c=labels, cmap='rainbow')


Cov = np.dot(genes_pc.T, genes_pc) / len(genes_pc)
T, D = np.linalg.eig(Cov)

plt.plot(genes_pc[:,0], genes_pc[:,1], 'k.', alpha=0.2)

pc1 = D[:, 1] * T[1]
plt.plot([0, pc1[0]], [0, pc1[1]], 'r-', linewidth=3)
plt.ylim(-20,20)

plt.xlabel("PC 1")
plt.ylabel("PC 2")
plt.title("PCA, K-Means, Eigen: PC2 vs PC 1 ")
